# %% [markdown]
# **Case Study on Regression**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/car_age_price.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    112 non-null    int64
#  1   Price   112 non-null    int64
# dtypes: int64(2)
# memory usage: 1.9 KB

# %%
data.head()
# Out:
#    Year   Price
# 0  2018  465000
# 1  2019  755000
# 2  2019  700000
# 3  2018  465000
# 4  2018  465000

# %%
data.describe()
# Out:
#               Year          Price
# count   112.000000     112.000000
# mean   2016.669643  483866.044643
# std       1.629616   91217.450533
# min    2013.000000  300000.000000
# 25%    2015.000000  423750.000000
# 50%    2017.000000  500000.000000
# 75%    2017.000000  550000.000000
# max    2020.000000  755000.000000

# %%
data["Year"].value_counts()
# Out:
# 2017    47
# 2015    22
# 2019    12
# 2018    11
# 2016     6
# 2014     6
# 2020     4
# 2013     4
# Name: Year, dtype: int64

# %%
data2=data[data.duplicated()]

# %%
data2
# Out:
#      Year   Price
# 3    2018  465000
# 4    2018  465000
# 9    2017  575000
# 15   2017  500000
# 16   2017  500000
# 18   2019  500000
# 19   2017  500000
# 20   2018  500000
# 21   2019  500000
# 23   2017  550000
# 24   2017  550000
# 25   2017  550000
# 26   2017  550000
# 27   2017  550000
# 28   2017  550000
# 29   2017  550000
# 31   2017  550000
# 32   2017  550000
# 33   2017  550000
# 35   2017  550000
# 36   2017  550000
# 41   2019  600000
# 44   2019  550000
# 46   2019  500000
# 47   2018  450000
# 51   2018  550000
# 53   2013  345000
# 55   2017  550000
# 57   2017  550000
# 62   2017  540000
# 64   2015  490000
# 66   2017  525000
# 72   2015  300000
# 74   2017  490000
# 75   2017  490000
# 76   2015  450000
# 79   2015  400000
# 82   2015  390000
# 84   2015  325000
# 87   2017  520000
# 88   2017  520000
# 89   2017  520000
# 90   2017  520000
# 91   2017  520000
# 92   2017  520000
# 93   2017  520000
# 94   2017  520000
# 95   2017  520000
# 96   2017  520000
# ...

# %%
data.drop_duplicates(inplace=True)

# %%
data.shape
# Out:
# (58, 2)

# %%
data["Year"].value_counts()
# Out:
# 2017    15
# 2015    12
# 2019     7
# 2018     6
# 2016     6
# 2014     5
# 2020     4
# 2013     3
# Name: Year, dtype: int64

# %%
data.isna().sum()
# Out:
# Year     0
# Price    0
# dtype: int64

# %% [markdown]
# Linear regression

# %%
x=data.drop(["Price"],axis=1)
y=data["Price"]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)
from sklearn import linear_model
lin_model=linear_model.LinearRegression()
model=lin_model.fit(x_train,y_train)
predict=model.predict(x_test)
from sklearn.metrics import mean_squared_error,r2_score
print("Mean Squared Error =",mean_squared_error(y_test,predict))
print("R Squared Error=",r2_score(y_test,predict))
# Out:
# Mean Squared Error = 4578558064.883415
# R Squared Error= 0.5952655854274035

# %% [markdown]
# Lasso model

# %%
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.1)
model=lasso.fit(x_train,y_train)
predict=model.predict(x_test)
print("Mean Squared Error=",mean_squared_error(y_test,predict))
print("R Squared Error=",r2_score(y_test,predict))
# Out:
# Mean Squared Error= 4578559309.462235
# R Squared Error= 0.5952654754093862

# %% [markdown]
#  Possible price of a 2022 model second-hand grand i10

# %%
x_2022=pd.DataFrame({'Year':[2022]})
predict=model.predict(x_2022)
import numpy as np
np.round(predict,2)
# Out:
# array([717501.46])
